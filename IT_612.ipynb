# %% [markdown]
# <a href="https://colab.research.google.com/github/fs1090/IT_612/blob/main/IT_612.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile main.js
# let x = 5;
# console.log(x);
# Out:
# Overwriting main.js

# %%
# !node main.js

function addTax(price, rate) => {}

function createBurner(secret, limit) {

}
# Out:
#   File "/tmp/ipython-input-1231264133.py", line 3
#     function addTax(price, rate) => {}
#              ^
# SyntaxError: invalid syntax
